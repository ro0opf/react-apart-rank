# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

api_key="o5i6RzX%2FRUqXjqw6iQbxeUZ6h1DnOg%2BLLDbQtvX9OleW0Y0%2FijNnBVjcb4maX22KrxTuZ79YZCPB4%2B8I%2FCZfwA%3D%3D"

def searchByRegionYM(deal_ymd,lawd_code): #년월, 지역코드(시군구 5자리)
    numOfRows = '10000' # 한번 노출 시 불러들이는 거래정보 량
    pageNo = '1' # 시작 페이지... 1회 호출에 10000건이 넘을 경우 다음페이지로 다시 호출 해야 함. 
    
    url = 'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?LAWD_CD=%s&DEAL_YMD=%s&ServiceKey=%s&numOfRows=%s&pageNo=%s' %(lawd_code, deal_ymd, api_key, numOfRows, pageNo)
    res = requests.get(url)

    print (res.text)
    
    soup = BeautifulSoup(res.text,'lxml-xml')
    it = soup.select('item')
    
    rows = []
    for node in it:
        try:
            n_serialNm = node.find('일련번호').text # 새로 생긴 단지의 경우 일련번호 없는 단지 있음. 
        except:
            n_serialNm =''
        
        try:
            n_add1 = node.find('지번').text # 지번이 없는 단지도 있음. 
        except:
            n_add1 = ''
        
        n_buildYear = node.find('건축년도').text
        n_dong = node.find('법정동').text
        n_aptName = node.find('아파트').text
        n_jySize = node.find('전용면적').text
        n_floor = node.find('층').text
        n_price = node.find('거래금액').text 
        n_tradeYear = node.find('년').text
        n_tradeMonth = node.find('월').text
        n_tradeDay = node.find('일').text
        n_siguCode = node.find('법정동시군구코드').text
        n_dongCode = node.find('법정동읍면동코드').text
        n_tradeYM = n_tradeYear +'-'+n_tradeMonth.rjust(2,'0')
        rows.append({'serialNm':n_serialNm,
                     'tradeYM':n_tradeYM,
                     'tradeDay':n_tradeDay,
                     'buildYear':n_buildYear,
                     'dong':n_dong,
                     'aptName':n_aptName,
                     'jySize':n_jySize,
                     'floor':n_floor,
                     'price':n_price,
                     'siguCode':n_siguCode,
                     'dongCode':n_dongCode,
                     'add1':n_add1,
                     })
        
    columns = ['serialNm','tradeYM','tradeDay','buildYear','dong','aptName','jySize','floor','price', 'siguCode', 'dongCode', 'add1' ]
    df = pd.DataFrame(rows, columns= columns)
    df['price'] = pd.to_numeric(df['price'].str.replace(',','')) # 특수 문자 바꾸기
    return df
# 지역코드 
# https://github.com/drtagkim/kor_gg_code/blob/master/region_code5.csv 참조

area1 = searchByRegionYM('202006','11110') # 2020년 6월 종로구 아파트 거래
area2 = searchByRegionYM('202006','11680') # 2020년 6월 강남구 아파트 거래
area3 = searchByRegionYM('202005','11680') # 2020년 5월 강남구 아파트 거래

# 2020년 강남구 전체 아파트 거래
import time
sum = pd.DataFrame()
for i in range(202001, 202006):
    df = searchByRegionYM(i,'11680') 
    sum = sum.append(df)
    time.sleep(10)
    
sum.to_csv('./kangnam.csv') # csv 파일로 저장 R로 분석하는게 편해서.
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>   121,500</거래금액><건축년도>2008</건축년도><년>2020</년><도로명>사직로8길</도로명><도로명건물본번호코드>00004</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11110</도로명시군구코드><도로명일련번호코드>03</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4100135</도로명코드><법정동> 사직동</법정동><법정동본번코드>0009</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11110</법정동시군구코드><법정동읍면동코드>11500</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>광화문풍림스페이스본(101동~105동)</아파트><월>6</월><일>4</일><일련번호>11110-2203</일련번호><전용면적>126.34</전용면적><지번>9</지번><지역코드>11110</지역코드><층>7</층></item><item><거래금액>   115,000</거래금액><건축년도>2008</건축년도><년>2020</년><도로명>사직로8길</도로명><도로명건물본번호코드>00004</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11110</도로명시군구코드><도로명일련번호코드>03</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4100135</도로명코드><법정동> 사직동</법정동><법정동본번코드>0009</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11110</법정동시군구코드><법정동읍면동코드>11500</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>광화문풍림스페이스본(101동~105동)</아파트><월>6</월><일>9</일><일련번호>11110-2203</일련번호><전용면적>94.28</전용면적><지번>9</지번><지역코드>11110</지역코드><층>5</층></item><item><거래금액>   113,000</거래금액><건축년도>2008</건축년도><년>2020</년><도로명>사직로8길</도로명><도로명건물본번호코드>00004</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11110</도로명시군구코드><도로명일련번호코드>03</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4100135</도로명코드><법정동> 사직동</법정동><법정동본번코드>0009</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11110</법정동시군구코드><법정동읍면동코드>11500</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>광화문풍림스페이스본(101동~105동)</아파트><월>6</월><일>13</일><일련번호>11110-2203</일련번호><전용면적>97.61</전용면적><지번>9</지번><지역코드>11110</지역코드><층>1</층></item><item><거래금액>   124,000</거래금액><건축년도>2008</건축년도><년>2020</년><도로명>사직로8길</도로명><도로명건물본번호코드>00004</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11110</도로명시군구코드><도로명일련번호코드>03</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4100135</도로명코드><법정동> 사직동</법정동><법정동본번코드>0009</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11110</법정동시군구코드><법정동읍면동코드>11500</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>광화문풍림스페이스본(101동~105동)</아파트><월>6</월><일>16</일><일련번호>11110-2203</일련번호><전용면적>94.51</전용면적><지번>9</지번><지역코드>11110</지역코드><층>5</층></item><item><거래금액>   120,000</거래금액><건축년도>2008</건축년도><년>2020</년><도로명>사직로8길</도로명><도로명건물본번호코드>00004</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11110</도로명시군구코드><도로명일련번호코드>03</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4100135</도로명코드><법정동> 사직동</법정동><법정동본번코드>0009</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11110</법정동시군구코드><법정동읍면동코드>11500</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>광화문풍림스페이스본(101동~105동)</아파트><월>6</월><일>20</일><일련번호>11110-2203</일련번호><전용면적>91.35</전용면적><지번>9</지번><지역코드>11110</지역코드><층>14</층></item><item><거래금액>   140,000</거래금액><건축년도>2004</건축년도><년>2020</년><도로명>사직로8길</도로명><도로명건물본번호코드>00024</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11110</도로명시군구코드><도로명일련번호코드>05</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4100135</도로명코드><법정동> 내수동</법정동><법정동본번코드>0071</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11110</법정동시군구코드><법정동읍면동코드>11800</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>경희궁의아침2단지</아파트><월>6</월><일>1</일><일련번호>11110-115</일련번호><전용면적>124.17</전용면적><지번>71</지번><지역코드>11110</지역코드><층>4</층></item><item><거래금액>    95,000</거래금액><건축년도>1994</건축년도><년>2020</년><도로명>새문안로3길</도로명><도로명건물본번호코드>00030</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11110</도로명시군구코드><도로명일련번호코드>02</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4100158</도로명코드><법정동> 내수동</법정동><법정동본번코드>0167</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11110</법정동시군구코드><법정동읍면동코드>11800</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>세종로대우</아파트><월>6</월><일>5</일><일련번호>11110-14</일련번호><전용면적>109.91</전용면적><지번>167</지번><지역코드>11110</지역코드><층>11</층></item><item><거래금액>   172,000</거래금액><건축년도>2004</건축년도><년>2020</년><도로명>사직로8길</도로명><도로명건물본번호코드>00034</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11110</도로명시군구코드><도로명일련번호코드>05</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4100135</도로명코드><법정동> 내수동</법정동><법정동본번코드>0072</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11110</법정동시군구코드><법정동읍면동코드>11800</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>경희궁의아침3단지</아파트><월>6</월><일> ...
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>   155,000</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00019</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0757</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼래미안</아파트><월>6</월><일>3</일><일련번호>11680-3621</일련번호><전용면적>59.53</전용면적><지번>757</지번><지역코드>11680</지역코드><층>12</층></item><item><거래금액>    79,000</거래금액><건축년도>2006</건축년도><년>2020</년><도로명>역삼로</도로명><도로명건물본번호코드>00307</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3122008</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0713</법정동본번코드><법정동부번코드>0011</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼 I'PARK</아파트><월>6</월><일>3</일><일련번호>11680-3679</일련번호><전용면적>28.246</전용면적><지번>713-11</지번><지역코드>11680</지역코드><층>11</층></item><item><거래금액>    40,120</거래금액><건축년도>2019</건축년도><년>2020</년><도로명>도곡로</도로명><도로명건물본번호코드>00113</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3122012</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0838</법정동본번코드><법정동부번코드>0010</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>강남웅진베어스빌</아파트><월>6</월><일>4</일><전용면적>18.61</전용면적><지번>838-10</지번><지역코드>11680</지역코드><층>14</층></item><item><거래금액>   196,500</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00019</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0757</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼래미안</아파트><월>6</월><일>5</일><일련번호>11680-3621</일련번호><전용면적>80.87</전용면적><지번>757</지번><지역코드>11680</지역코드><층>3</층></item><item><거래금액>    36,000</거래금액><건축년도>1996</건축년도><년>2020</년><도로명>도곡로3길</도로명><도로명건물본번호코드>00026</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166232</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0836</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>한스빌(836)</아파트><월>6</월><일>6</일><일련번호>11680-251</일련번호><전용면적>39.89</전용면적><지번>836</지번><지역코드>11680</지역코드><층>12</층></item><item><거래금액>   270,000</거래금액><건축년도>2006</건축년도><년>2020</년><도로명>역삼로</도로명><도로명건물본번호코드>00314</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3122008</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0755</법정동본번코드><법정동부번코드>0001</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>개나리 푸르지오</아파트><월>6</월><일>6</일><일련번호>11680-3678</일련번호><전용면적>133.1686</전용면적><지번>755-1</지번><지역코드>11680</지역코드><층>24</층></item><item><거래금액>    92,500</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>언주로103길</도로명><도로명건물본번호코드>00016</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166559</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0656</법정동본번코드><법정동부번코드>0030</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼엔스위트1</아파트><월>6</월><일>7</일><일련번호>11680-593</일련번호><전용면적>107.3</전용면적><지번>656-30</지번><지역코드>11680</지역코드><층>5</층></item><item><거래금액>   250,000</거래금액><건축년도>2006</건축년도><년>2020</년><도로명>역삼로</도로명><도로명건물본번호코드>00307</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3122008</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0713</법정동본번코드><법정동부번코드>0011</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼 I'PARK</아파트><월>6</월><일>8</일><일련번호>11680-3679</일련번호><전용면적>131.38</전용면적><지번>713-11</지번><지역코드>11680 ...
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    85,700</거래금액><건축년도>2004</건축년도><년>2020</년><도로명>언주로103길</도로명><도로명건물본번호코드>00012</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166559</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0656</법정동본번코드><법정동부번코드>0032</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼동그린비</아파트><월>5</월><일>1</일><일련번호>11680-489</일련번호><전용면적>106.69</전용면적><지번>656-32</지번><지역코드>11680</지역코드><층>4</층></item><item><거래금액>   119,000</거래금액><건축년도>2002</건축년도><년>2020</년><도로명>언주로85길</도로명><도로명건물본번호코드>00013</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166618</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0722</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>경남아너스빌</아파트><월>5</월><일>4</일><일련번호>11680-276</일련번호><전용면적>81.013</전용면적><지번>722</지번><지역코드>11680</지역코드><층>16</층></item><item><거래금액>   147,900</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00019</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0757</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼래미안</아파트><월>5</월><일>5</일><일련번호>11680-3621</일련번호><전용면적>59.53</전용면적><지번>757</지번><지역코드>11680</지역코드><층>1</층></item><item><거래금액>   225,000</거래금액><건축년도>2014</건축년도><년>2020</년><도로명>테헤란로52길</도로명><도로명건물본번호코드>00016</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166745</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0709</법정동본번코드><법정동부번코드>0005</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>테헤란아이파크</아파트><월>5</월><일>5</일><일련번호>11680-4296</일련번호><전용면적>92.6232</전용면적><지번>709-5</지번><지역코드>11680</지역코드><층>3</층></item><item><거래금액>   170,000</거래금액><건축년도>2007</건축년도><년>2020</년><도로명>도곡로13길</도로명><도로명건물본번호코드>00019</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166214</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0835</법정동본번코드><법정동부번코드>0068</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>롯데캐슬노블</아파트><월>5</월><일>5</일><일련번호>11680-3728</일련번호><전용면적>176.03</전용면적><지번>835-68</지번><지역코드>11680</지역코드><층>2</층></item><item><거래금액>    85,500</거래금액><건축년도>2002</건축년도><년>2020</년><도로명>언주로75길</도로명><도로명건물본번호코드>00022</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166614</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0729</법정동본번코드><법정동부번코드>0037</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>명인갤러리</아파트><월>5</월><일>7</일><일련번호>11680-261</일련번호><전용면적>84.78</전용면적><지번>729-37</지번><지역코드>11680</지역코드><층>5</층></item><item><거래금액>   152,500</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00019</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0757</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼래미안</아파트><월>5</월><일>7</일><일련번호>11680-3621</일련번호><전용면적>59.4</전용면적><지번>757</지번><지역코드>11680</지역코드><층>10</층></item><item><거래금액>    47,000</거래금액><건축년도>2002</건축년도><년>2020</년><도로명>언주로63길</도로명><도로명건물본번호코드>00030</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166606</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0783</법정동본번코드><법정동부번코드>0028</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>갤러리아트</아파트><월>5</월><일>8</일><일련번호>11680-272</일련번호><전용면적>53.65</전용면적><지번>783-2 ...
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    77,000</거래금액><건축년도>2004</건축년도><년>2020</년><도로명>역삼로34길</도로명><도로명건물본번호코드>00012</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166645</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0775</법정동본번코드><법정동부번코드>0015</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>현대하이츠</아파트><월>1</월><일>3</일><일련번호>11680-586</일련번호><전용면적>99.22</전용면적><지번>775-15</지번><지역코드>11680</지역코드><층>4</층></item><item><거래금액>    20,200</거래금액><건축년도>2003</건축년도><년>2020</년><도로명>언주로90길</도로명><도로명건물본번호코드>00006</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166622</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0706</법정동본번코드><법정동부번코드>0011</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>우림루미아트1</아파트><월>1</월><일>3</일><일련번호>11680-665</일련번호><전용면적>24</전용면적><지번>706-11</지번><지역코드>11680</지역코드><층>8</층></item><item><거래금액>    39,500</거래금액><건축년도>1996</건축년도><년>2020</년><도로명>도곡로3길</도로명><도로명건물본번호코드>00026</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166232</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0836</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>한스빌(836)</아파트><월>1</월><일>4</일><일련번호>11680-251</일련번호><전용면적>41.95</전용면적><지번>836</지번><지역코드>11680</지역코드><층>11</층></item><item><거래금액>   148,800</거래금액><건축년도>1998</건축년도><년>2020</년><도로명>선릉로</도로명><도로명건물본번호코드>00423</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3122006</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0716</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>동부센트레빌</아파트><월>1</월><일>6</일><일련번호>11680-237</일련번호><전용면적>59.82</전용면적><지번>716</지번><지역코드>11680</지역코드><층>21</층></item><item><거래금액>    85,000</거래금액><건축년도>2012</건축년도><년>2020</년><도로명>논현로63길</도로명><도로명건물본번호코드>00016</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166184</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0796</법정동본번코드><법정동부번코드>0029</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>강남서해더블루</아파트><월>1</월><일>6</일><일련번호>11680-4050</일련번호><전용면적>62.26</전용면적><지번>796-29</지번><지역코드>11680</지역코드><층>10</층></item><item><거래금액>    20,400</거래금액><건축년도>2003</건축년도><년>2020</년><도로명>언주로90길</도로명><도로명건물본번호코드>00006</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166622</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0706</법정동본번코드><법정동부번코드>0011</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>우림루미아트1</아파트><월>1</월><일>6</일><일련번호>11680-665</일련번호><전용면적>23.9</전용면적><지번>706-11</지번><지역코드>11680</지역코드><층>7</층></item><item><거래금액>    56,000</거래금액><건축년도>2002</건축년도><년>2020</년><도로명>도곡로57길</도로명><도로명건물본번호코드>00009</도로명건물본번호코드><도로명건물부번호코드>00007</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166236</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0766</법정동본번코드><법정동부번코드>0008</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>트레벨</아파트><월>1</월><일>6</일><일련번호>11680-274</일련번호><전용면적>33.48</전용면적><지번>766-8</지번><지역코드>11680</지역코드><층>4</층></item><item><거래금액>    74,950</거래금액><건축년도>2002</건축년도><년>2020</년><도로명>도곡로33길</도로명><도로명건물본번호코드>00016</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166227</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0783</법정동본번코드><법정동부번코드>0003</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>갤러리하우스</아파트><월>1</월><일>9</일><일련번호>11680-271</일련번호><전용면적>76.52</전용면적><지번>783-3</지번><지역코 ...
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>   149,000</거래금액><건축년도>2002</건축년도><년>2020</년><도로명>언주로85길</도로명><도로명건물본번호코드>00013</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166618</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0722</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>경남아너스빌</아파트><월>2</월><일>1</일><일련번호>11680-276</일련번호><전용면적>84.688</전용면적><지번>722</지번><지역코드>11680</지역코드><층>4</층></item><item><거래금액>   167,000</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00020</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0755</법정동본번코드><법정동부번코드>0004</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>e-편한세상</아파트><월>2</월><일>1</일><일련번호>11680-3622</일련번호><전용면적>59.606</전용면적><지번>755-4</지번><지역코드>11680</지역코드><층>10</층></item><item><거래금액>    70,000</거래금액><건축년도>2004</건축년도><년>2020</년><도로명>테헤란로4길</도로명><도로명건물본번호코드>00032</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166743</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0826</법정동본번코드><법정동부번코드>0029</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼동우정에쉐르1</아파트><월>2</월><일>1</일><일련번호>11680-504</일련번호><전용면적>71.78</전용면적><지번>826-29</지번><지역코드>11680</지역코드><층>2</층></item><item><거래금액>    36,000</거래금액><건축년도>2001</건축년도><년>2020</년><도로명>언주로86길</도로명><도로명건물본번호코드>00011</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166619</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0706</법정동본번코드><법정동부번코드>0020</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>한화진넥스빌</아파트><월>2</월><일>3</일><일련번호>11680-249</일련번호><전용면적>39.2</전용면적><지번>706-20</지번><지역코드>11680</지역코드><층>19</층></item><item><거래금액>   171,000</거래금액><건축년도>2006</건축년도><년>2020</년><도로명>언주로</도로명><도로명건물본번호코드>00332</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3005086</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0754</법정동본번코드><법정동부번코드>0001</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼푸르지오</아파트><월>2</월><일>5</일><일련번호>11680-3643</일련번호><전용면적>59.8848</전용면적><지번>754-1</지번><지역코드>11680</지역코드><층>11</층></item><item><거래금액>    72,000</거래금액><건축년도>2003</건축년도><년>2020</년><도로명>도곡로19길</도로명><도로명건물본번호코드>00013</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166218</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0794</법정동본번코드><법정동부번코드>0024</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>노블카운티</아파트><월>2</월><일>8</일><일련번호>11680-463</일련번호><전용면적>81.85</전용면적><지번>794-24</지번><지역코드>11680</지역코드><층>1</층></item><item><거래금액>   179,000</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00020</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0755</법정동본번코드><법정동부번코드>0004</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>e-편한세상</아파트><월>2</월><일>9</일><일련번호>11680-3622</일련번호><전용면적>59.947</전용면적><지번>755-4</지번><지역코드>11680</지역코드><층>12</층></item><item><거래금액>    90,000</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>역삼로</도로명><도로명건물본번호코드>00109</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3122008</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0831</법정동본번코드><법정동부번코드>0045</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>에스케이허브젠</아파트><월>2</월><일>10</일><일련번호>11680-3615</일련번호><전용면적>71.91</전용면적><지번> ...
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>   249,000</거래금액><건축년도>2010</건축년도><년>2020</년><도로명>도곡로43길</도로명><도로명건물본번호코드>00021</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166233</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0762</법정동본번코드><법정동부번코드>0003</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>래미안그레이튼(진달래2차)</아파트><월>3</월><일>4</일><일련번호>11680-3905</일련번호><전용면적>121.54</전용면적><지번>762-3</지번><지역코드>11680</지역코드><층>33</층></item><item><거래금액>    21,000</거래금액><건축년도>2012</건축년도><년>2020</년><도로명>역삼로25길</도로명><도로명건물본번호코드>00027</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166641</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0727</법정동본번코드><법정동부번코드>0002</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>대명벨리온</아파트><월>3</월><일>5</일><일련번호>11680-4036</일련번호><전용면적>17.684</전용면적><지번>727-2</지번><지역코드>11680</지역코드><층>3</층></item><item><거래금액>   167,000</거래금액><건축년도>2006</건축년도><년>2020</년><도로명>언주로</도로명><도로명건물본번호코드>00332</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3005086</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0754</법정동본번코드><법정동부번코드>0001</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼푸르지오</아파트><월>3</월><일>6</일><일련번호>11680-3643</일련번호><전용면적>59.8848</전용면적><지번>754-1</지번><지역코드>11680</지역코드><층>21</층></item><item><거래금액>    83,000</거래금액><건축년도>1996</건축년도><년>2020</년><도로명>도곡로23길</도로명><도로명건물본번호코드>00032</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166222</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0797</법정동본번코드><법정동부번코드>0012</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>우성빌라트</아파트><월>3</월><일>7</일><일련번호>11680-244</일련번호><전용면적>129.72</전용면적><지번>797-12</지번><지역코드>11680</지역코드><층>1</층></item><item><거래금액>   243,000</거래금액><건축년도>2014</건축년도><년>2020</년><도로명>테헤란로52길</도로명><도로명건물본번호코드>00016</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166745</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0709</법정동본번코드><법정동부번코드>0005</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>테헤란아이파크</아파트><월>3</월><일>7</일><일련번호>11680-4296</일련번호><전용면적>92.6232</전용면적><지번>709-5</지번><지역코드>11680</지역코드><층>21</층></item><item><거래금액>   125,000</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>도곡로21길</도로명><도로명건물본번호코드>00015</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166220</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0795</법정동본번코드><법정동부번코드>0041</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼동월드메르디앙</아파트><월>3</월><일>7</일><일련번호>11680-3570</일련번호><전용면적>81.76</전용면적><지번>795-41</지번><지역코드>11680</지역코드><층>7</층></item><item><거래금액>    52,000</거래금액><건축년도>2003</건축년도><년>2020</년><도로명>논현로71길</도로명><도로명건물본번호코드>00048</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166192</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0789</법정동본번코드><법정동부번코드>0029</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>지석천평대</아파트><월>3</월><일>7</일><일련번호>11680-462</일련번호><전용면적>59.77</전용면적><지번>789-29</지번><지역코드>11680</지역코드><층>7</층></item><item><거래금액>    39,000</거래금액><건축년도>1996</건축년도><년>2020</년><도로명>도곡로3길</도로명><도로명건물본번호코드>00026</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166232</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0836</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>한스빌(836)</아파트><월>3</월><일>9</일><일련번호>11680-251</일련번호><전용면적>5 ...
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>   148,000</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00019</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0757</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼래미안</아파트><월>4</월><일>1</일><일련번호>11680-3621</일련번호><전용면적>59.4</전용면적><지번>757</지번><지역코드>11680</지역코드><층>21</층></item><item><거래금액>    22,000</거래금액><건축년도>2012</건축년도><년>2020</년><도로명>역삼로25길</도로명><도로명건물본번호코드>00027</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166641</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0727</법정동본번코드><법정동부번코드>0002</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>대명벨리온</아파트><월>4</월><일>1</일><일련번호>11680-4036</일련번호><전용면적>17.684</전용면적><지번>727-2</지번><지역코드>11680</지역코드><층>3</층></item><item><거래금액>   161,000</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00020</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0755</법정동본번코드><법정동부번코드>0004</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>e-편한세상</아파트><월>4</월><일>4</일><일련번호>11680-3622</일련번호><전용면적>59.606</전용면적><지번>755-4</지번><지역코드>11680</지역코드><층>3</층></item><item><거래금액>   150,000</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00020</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0755</법정동본번코드><법정동부번코드>0004</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>e-편한세상</아파트><월>4</월><일>11</일><일련번호>11680-3622</일련번호><전용면적>59.606</전용면적><지번>755-4</지번><지역코드>11680</지역코드><층>7</층></item><item><거래금액>   223,000</거래금액><건축년도>2006</건축년도><년>2020</년><도로명>역삼로</도로명><도로명건물본번호코드>00314</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3122008</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0755</법정동본번코드><법정동부번코드>0001</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>개나리 푸르지오</아파트><월>4</월><일>16</일><일련번호>11680-3678</일련번호><전용면적>84.9876</전용면적><지번>755-1</지번><지역코드>11680</지역코드><층>13</층></item><item><거래금액>   200,000</거래금액><건축년도>2006</건축년도><년>2020</년><도로명>언주로</도로명><도로명건물본번호코드>00332</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3005086</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0754</법정동본번코드><법정동부번코드>0001</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼푸르지오</아파트><월>4</월><일>17</일><일련번호>11680-3643</일련번호><전용면적>84.9097</전용면적><지번>754-1</지번><지역코드>11680</지역코드><층>3</층></item><item><거래금액>   250,000</거래금액><건축년도>2006</건축년도><년>2020</년><도로명>역삼로</도로명><도로명건물본번호코드>00306</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>3122008</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0754</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>개나리래미안</아파트><월>4</월><일>17</일><일련번호>11680-3680</일련번호><전용면적>144.98</전용면적><지번>754</지번><지역코드>11680</지역코드><층>16</층></item><item><거래금액>   153,000</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00019</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0757</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼래미안</아파트><월>4</월><일>18</일><일련번호>11680-3621</일련번호><전용면적>59.4</전용면적><지번>757 ...
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    85,700</거래금액><건축년도>2004</건축년도><년>2020</년><도로명>언주로103길</도로명><도로명건물본번호코드>00012</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166559</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0656</법정동본번코드><법정동부번코드>0032</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼동그린비</아파트><월>5</월><일>1</일><일련번호>11680-489</일련번호><전용면적>106.69</전용면적><지번>656-32</지번><지역코드>11680</지역코드><층>4</층></item><item><거래금액>   119,000</거래금액><건축년도>2002</건축년도><년>2020</년><도로명>언주로85길</도로명><도로명건물본번호코드>00013</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166618</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0722</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>경남아너스빌</아파트><월>5</월><일>4</일><일련번호>11680-276</일련번호><전용면적>81.013</전용면적><지번>722</지번><지역코드>11680</지역코드><층>16</층></item><item><거래금액>   147,900</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00019</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0757</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼래미안</아파트><월>5</월><일>5</일><일련번호>11680-3621</일련번호><전용면적>59.53</전용면적><지번>757</지번><지역코드>11680</지역코드><층>1</층></item><item><거래금액>   225,000</거래금액><건축년도>2014</건축년도><년>2020</년><도로명>테헤란로52길</도로명><도로명건물본번호코드>00016</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166745</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0709</법정동본번코드><법정동부번코드>0005</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>테헤란아이파크</아파트><월>5</월><일>5</일><일련번호>11680-4296</일련번호><전용면적>92.6232</전용면적><지번>709-5</지번><지역코드>11680</지역코드><층>3</층></item><item><거래금액>   170,000</거래금액><건축년도>2007</건축년도><년>2020</년><도로명>도곡로13길</도로명><도로명건물본번호코드>00019</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166214</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0835</법정동본번코드><법정동부번코드>0068</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>롯데캐슬노블</아파트><월>5</월><일>5</일><일련번호>11680-3728</일련번호><전용면적>176.03</전용면적><지번>835-68</지번><지역코드>11680</지역코드><층>2</층></item><item><거래금액>    85,500</거래금액><건축년도>2002</건축년도><년>2020</년><도로명>언주로75길</도로명><도로명건물본번호코드>00022</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166614</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0729</법정동본번코드><법정동부번코드>0037</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>명인갤러리</아파트><월>5</월><일>7</일><일련번호>11680-261</일련번호><전용면적>84.78</전용면적><지번>729-37</지번><지역코드>11680</지역코드><층>5</층></item><item><거래금액>   152,500</거래금액><건축년도>2005</건축년도><년>2020</년><도로명>선릉로69길</도로명><도로명건물본번호코드>00019</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166489</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0757</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>역삼래미안</아파트><월>5</월><일>7</일><일련번호>11680-3621</일련번호><전용면적>59.4</전용면적><지번>757</지번><지역코드>11680</지역코드><층>10</층></item><item><거래금액>    47,000</거래금액><건축년도>2002</건축년도><년>2020</년><도로명>언주로63길</도로명><도로명건물본번호코드>00030</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11680</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4166606</도로명코드><법정동> 역삼동</법정동><법정동본번코드>0783</법정동본번코드><법정동부번코드>0028</법정동부번코드><법정동시군구코드>11680</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>갤러리아트</아파트><월>5</월><일>8</일><일련번호>11680-272</일련번호><전용면적>53.65</전용면적><지번>783-2 ...
